# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroHCasarotto/Inteligencia-Artificial/blob/main/%5BFinclass%5D_An%C3%A1lise_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Para baixar o seu Notebook e poder alterar as informações, siga o seguinte processo: "Arquivo > Salvar uma cópia no Drive". Você também pode baixar o Notebook através de: "Arquivo > Fazer download > Fazer download do .ipynb"

# %% [markdown]
# #### **Data Science para Finanças**
# *por [Carlos Melo - Sigmoidal](https://escola.sigmoidal.ai/curso-python-do-zero/)*
#
# ---
#
# <h1>Conhecendo o Jupyter Notebook</h1>
#
# Google Colab é um ambiente Jupyter notebook que roda inteiramente na nuvem. Ou seja, você consegue criar e rodar seus projetos de Data Science sem perder tempo configurando sua máquina local.
#
# <center><img src="https://miro.medium.com/max/2000/1*gl0OdcvY4lnkSB8WvOghvw.jpeg" height="400px"></center>
#
# ## Ambiente Interativo
#
# Uma das principais vantagens de se usar Jupyter notebooks no lugar de IDE convencionais para criar seus projetos, é porque esta página não é estática. Quando você cria um arquivo aqui, qualquer pessoa vai conseguir rodar seu código e fazer suas próprias alterações.
#
# Isto é perfeito! Imagina uma situação onde você fez uma análise para a sua empresa, 6 meses atrás. Determinado dia, o Diretor de vendas pede para você calcular uma informação completamente nova em cima daquela análise.
#
# Se você tem apenas o relatório estático (ou mesmo um monte de arquivos .py, sem documentação), as chances são que você não vai ser capaz de entregrar a informação nova em tempo ábil.
#
# Agora, se você tem salvo todos os seus notebooks de maneira organizada, preferencialmente na nuvem, você pode executar todas as células novamente e apenas incluir mais essa análise extra.
#
# Veja como é fácil trabalhar com céulas interativas.

# %%
# operações matemáticas com Python
receita = 14800.90
despesa_fixa = 4500
despesa_variavel = 3600.90

lucro = receita - (despesa_fixa + despesa_variavel)

print(lucro)
# Out:
# 6700.0

# %% [markdown]
# A célula acima é nossa primeira contendo código. Todas as anteriores (incluindo este) eram texto puro.
#
# Dê dois cliques na célula acima para editar, altere o valor de alguma varíavel (receita, por exemplo) e aperte **SHIFT + ENTER** (ou clique no ícone "Play" na esquerda dela. Essa é a vantagem de se documentar um projeto pelo Jupyter notebook, você torna ele replicável.
#
# ## Atalhos do Jupyter
#
# Saber os atalhos do Jupyter vai ajudar você a ganhar tempo. Apesar de você sempre poder recorrer ao menu lá em cima, recomendo você já ir se acostumando com as principais combinações de teclas. Aqui estão algumas delas:
#
# * Aperte **Shift + Enter** para executar a célula selecionada;
# * Aperte **Ctrl/Cmd + M** seguindo por **B** para criar uma célula nóva abaixo;
# * Aperte **Ctrl/Cmd + M** seguindo por **A** para criar uma célula nóva acima;
# * Aperte **Ctrl/Cmd + M** seguindo por **M** para definir a célula selecionada como tipo Texto;
# * Aperte **Ctrl/Cmd + M** seguindo por **Y** para definir a célula selecionada como tipo Código;
#
# ## Integração com o Sistema
#
# Outra coisa que o Jupyter notebook possibilita é você acessar o próprio sistema, tudo a partir da célula de código.
#
# Se você está acostumado a usar linha de comando no Terminal, por exemplo, pode integrar seu código Python com essa possibilidade.
#
# Por exemplo, para eu listar todos os arquivos da pasta atual:

# %%
# !ls / -l
# Out:
# total 100
# drwxr-xr-x   1 root root 4096 Apr 25 13:36 bin
# drwxr-xr-x   2 root root 4096 Apr 24  2018 boot
# drwxr-xr-x   1 root root 4096 Apr 26 22:19 content
# drwxr-xr-x   1 root root 4096 Apr 25 14:02 datalab
# drwxr-xr-x   5 root root  360 Apr 26 22:18 dev
# drwxr-xr-x   1 root root 4096 Apr 26 22:18 etc
# drwxr-xr-x   2 root root 4096 Apr 24  2018 home
# drwxr-xr-x   1 root root 4096 Apr 25 13:37 lib
# drwxr-xr-x   2 root root 4096 Apr 25 13:25 lib32
# drwxr-xr-x   1 root root 4096 Apr 25 13:25 lib64
# drwxr-xr-x   2 root root 4096 Nov 19  2020 media
# drwxr-xr-x   2 root root 4096 Nov 19  2020 mnt
# drwxr-xr-x   1 root root 4096 Apr 25 13:39 opt
# dr-xr-xr-x 168 root root    0 Apr 26 22:18 proc
# drwxr-xr-x  14 root root 4096 Apr 25 13:38 python-apt
# drwx------   1 root root 4096 Apr 26 22:19 root
# drwxr-xr-x   1 root root 4096 Apr 25 13:28 run
# drwxr-xr-x   1 root root 4096 Apr 26 22:18 sbin
# drwxr-xr-x   2 root root 4096 Nov 19  2020 srv
# dr-xr-xr-x  12 root root    0 Apr 26 22:18 sys
# drwxr-xr-x   3 root root 4096 Apr 25 13:59 tensorflow-1.15.2
# drwxrwxrwt   1 root root 4096 Apr 26 22:19 tmp
# drwxr-xr-x   1 root root 4096 Apr 25 14:02 tools
# drwxr-xr-x   1 root root 4096 Apr 25 13:39 usr
# drwxr-xr-x   1 root root 4096 Apr 26 22:18 var

# %% [markdown]
# ### Importar arquivos `csv` com as cotações do BBAS3.SA
#
# Para dar um exemplo de como é simples importar dados com o Pandas, veja o seguinte exemplo.
#
# Pelo site [Yahoo Finance](https://finance.yahoo.com/quote/BBAS3.SA/history?p=BBAS3.SA), baixei os dados da ação ordinária do Banco do Brasil (BBAS3) em formato `csv` e disponibilizei o arquivo [neste link](https://raw.githubusercontent.com/carlosfab/curso_data_science_na_pratica/master/modulo_02/BBAS3.SA.csv). Se eu abrir esse arquivo na minha máquina pelo Excel, é assim que ele vai aparecer para mim:
#
# <center><img src="https://raw.githubusercontent.com/carlosfab/curso_data_science_na_pratica/master/modulo_02/bbas3_excel.png" height="300px"></center>
#
# Importar esse mesmo arquivo usando o Pandas é tão simples quanto executar a função `pd.read_csv("local_do_arquivo.csv")`, informando qual o endereço que o `csv` se encontra (endereço na internet ou caminho na máquia local.
#
#
#
# Também é possível baixar arquivos por comandos do Terminal, criar diretórios e automatizar *pipelines*. Isso contribui mais ainda para que seu notebook seja replicável por qualquer pessoa.
#
# Vamos supor que você está usando um arquivo csv que se encontra no endereço ```https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/BBAS3.SA.csv``` e quer baixar o mesmo:

# %%
# baixar o arquivo BBAS3.SA.csv
# !wget https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/BBAS3.SA.csv

# ver o diretório
# !ls -l
# Out:
# --2022-04-26 22:53:58--  https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/BBAS3.SA.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17286 (17K) [text/plain]
# Saving to: ‘BBAS3.SA.csv.1’
#
# BBAS3.SA.csv.1      100%[===================>]  16.88K  --.-KB/s    in 0s
#
# 2022-04-26 22:53:58 (39.4 MB/s) - ‘BBAS3.SA.csv.1’ saved [17286/17286]
#
# total 48
# -rw-r--r-- 1 root root 17286 Apr 26 22:19 BBAS3.SA.csv
# -rw-r--r-- 1 root root 17286 Apr 26 22:53 BBAS3.SA.csv.1
# drwxr-xr-x 1 root root  4096 Apr 25 13:46 sample_data
# -rw-r--r-- 1 root root  1273 Apr 26 22:19 sigmoidal.png

# %% [markdown]
# Pronto! O arquivo `BBAS3.SA.csv` foi importado com sucesso e já está pronto para ser usado neste *notebook*.
#
# ### Conhecendo os componentes básicos do Pandas
#
# Os dois componentes básicos que a gente deve conhecer quando lidando com Pandas são `Series` e `DataFrame`.
#
# <center><img src="https://raw.githubusercontent.com/carlosfab/curso_data_science_na_pratica/master/modulo_02/componentes_pandas.png"></center>
#
# Simplificadamente, você pode pensar o `DataFrame` como sendo uma planilha de Excel, e `Series` como sendo apenas uma coluna individual.
#
# Apesar de parecer conceitualmente simples, estas duas estruturas nativas do Pandas facilitam muito o trabalho com dados, uma vez que elas podem armazenar qualquer tipo de dado.

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/BBAS3.SA.csv")

# %%
df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  247.000000  247.000000  247.000000  247.000000  247.000000
# mean    45.939960   46.576397   45.154615   45.838097   44.684901
# std      7.644318    7.475109    7.858680    7.704523    7.210382
# min     24.200001   25.000000   21.910000   22.129999   22.129999
# 25%     45.425002   46.145001   44.774999   45.415001   44.072172
# 50%     48.139999   48.779999   47.560001   47.990002   46.766251
# 75%     50.535000   51.125000   49.785000   50.460001   49.133178
# max     55.599998   55.700001   54.820000   55.180000   53.052986
#
#              Volume
# count  2.470000e+02
# mean   1.405295e+07
# std    8.021174e+06
# min    5.092200e+06
# 25%    8.997050e+06
# 50%    1.198600e+07
# 75%    1.587985e+07
# max    7.397800e+07

# %% [markdown]
# ## Documentação por *Markdown*
#
# No Colab, você não precisa obrigatoriamente usar Markdown para conseguir documentar o seu texto. Há um mini editor disponível.
#
# Assim, é mais fácil definir quais os cabeçalhos, colocar em negrito ou itálico, interir tópicos ou mesmo imagens.
#
# ### Equações e Fórmulas com LaTex
#
# Um outro recurso muito poderoso é o uso de *LaTex* dentro do *notebook*. Você consegue escrever equações, formulas matemáticas, usar símbolos especiais da mesma maneira que faria no seu editor.
#
# Há a possibilidade de se criar diagramas, grafos e representar matrizes - tudo com *LaTex*!
#
# $$
# \begin{equation*}
# \left( \sum_{k=1}^n a_k b_k \right)^2 \leq \left( \sum_{k=1}^n a_k^2 \right) \left( \sum_{k=1}^n b_k^2 \right)
# \end{equation*}
# $$
#
# $$
# \mathbf{J}
# =
# \frac{d \mathbf{f}}{d \mathbf{x}}
# =
# \left[ \frac{\partial \mathbf{f}}{\partial x_1}
# \cdots \frac{\partial \mathbf{f}}{\partial x_n} \right]
# =
# \begin{bmatrix}
# \frac{\partial f_1}{\partial x_1} & \cdots &
# \frac{\partial f_1}{\partial x_n} \\
# \vdots & \ddots & \vdots \\
# \frac{\partial f_m}{\partial x_1} & \cdots &
# \frac{\partial f_m}{\partial x_n}
# \end{bmatrix}
# $$

# %% [markdown]
# ## Gráficos no Colab
#
# Gráficos vão fazer parte do seu dia a dia. Por tamanha a importância, teremos um módulo inteiramente dedicado a eles, onde vamos explorar as bibliotecas ```matplotlib``` e ```seaborn```.
#
# Você não precisa entender o código abaixo ainda, apenas ver como é possível gerar um facilmente por aqui.
#
# ### Histogramas

# %%
# importar matplotlib
import matplotlib.pyplot as plt

# plotar histograma

# %%
df['Volume'].std()
# Out:
# 8021174.313261291

# %%
plt.hist(df['Volume'], bins=10);

# %% [markdown]
# ### Scatter Plots

# %%
plt.scatter(df["Open"], df["Low"])

plt.savefig('sigmoidal.png')

# %% [markdown]
# ## Formulários
#
# Aqui no Colab, há a possibilidade de se criar formulários interativos, que passam o valor para a variável. É uma ótima abordagem quando você tem que realizar vários testes para ajustes de parâmetros ou precisa receber um input de valor digitado.

# %%
#@title Exemplos de Campos {run: "auto"}

texto = 'Ativo da Carteira' #@param {type:"string"}
melhor_cidade = 'PETR4' #@param ["BBAS3", "PETR4", "PETR3"]
data_curso = '2019-09-18' #@param {type:"date"}
number_slider = 5.5 #@param {type:"slider", min:0, max:10, step:0.1}
boolean_checkbox = True #@param {type:"boolean"}

# imprimir os valores dos formulários
print(texto)
print(melhor_cidade)
print(data_curso)
print(number_slider)
print(boolean_checkbox)

# %% [markdown]
# Para os valores serem atualizados, você tem que executar a célula antes, clicando no botão **Play** ou com **Shift + Enter**.
#
# Uma alternativa, éincluir ```run: "auto"``` na primeira linha. Assim, após a primeira vez que você rodar a célula, caso mude futuramente o valor, ela executará automaticamente a mesma (atualizando o valor da variável atribuida).
#
# E lembrando que você consegue esconder a parte do código, deixando apenas o formulário. Basta clicar na célular, ir em **View → Show/hide code** (isso também é possível de fazer usando a barra de ferramentas que fica no canto superior direito de cada célula).
#
# ## Importando uma biblioteca que não está instalada
#
# O ambiente do Colab já vem com as principais bibliotecas para Machine Learning e Data Science. No entanto, caso haja a necessidade de instalar qualquer pacote adicional, a instalação pode ser feita com o ```pip install```.

# %%
import numpy as np

# %%
# !pip install yfinance -q
# !pip install quantstats -q

# %%
import pandas as pd
import requests
# import wget
from zipfile import ZipFile
import numpy as np
from datetime import datetime
import yfinance as yf
import quantstats as qs
import plotly.graph_objects as go
from plotly.subplots import make_subplots
pd.set_option("display.max_colwidth", 150)

# %%
import yfinance as yf

lista_ativos = ["BBAS3.SA", "MGLU3.SA"]
dados_ativos = yf.download(lista_ativos, start='2018-01-01', period='1D')["High"]
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
dados_ativos
# Out:
#              BBAS3.SA  MGLU3.SA
# Date
# 2018-01-02  32.930000  2.574375
# 2018-01-03  33.419998  2.542500
# 2018-01-04  33.959999  2.516250
# 2018-01-05  33.900002  2.528437
# 2018-01-08  33.750000  2.503437
# ...               ...       ...
# 2022-04-19  36.680000  6.020000
# 2022-04-20  35.270000  6.040000
# 2022-04-22  34.770000  5.590000
# 2022-04-25  34.950001  5.570000
# 2022-04-26  34.560001  5.470000
#
# [1067 rows x 2 columns]

# %%
grande = yf.download(lista_ativos, start='2018-01-01', period='1D')
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
grande["Volume"].head()
# Out:
#             BBAS3.SA  MGLU3.SA
# Date
# 2018-01-02   9178100  59427200
# 2018-01-03   8180700  41385600
# 2018-01-04   9625200  47936000
# 2018-01-05   5267800  30684800
# 2018-01-08   5130600  28796800

# %%
grande
# Out:
#             Adj Close                Close                 High            \
#              BBAS3.SA  MGLU3.SA   BBAS3.SA  MGLU3.SA   BBAS3.SA  MGLU3.SA
# Date
# 2018-01-02  25.657843  2.390916  32.930000  2.478125  32.930000  2.574375
# 2018-01-03  25.985088  2.360766  33.349998  2.446875  33.419998  2.542500
# 2018-01-04  26.234423  2.417449  33.669998  2.505625  33.959999  2.516250
# 2018-01-05  26.234423  2.369810  33.669998  2.456250  33.900002  2.528437
# 2018-01-08  26.296755  2.370112  33.750000  2.456562  33.750000  2.503437
# ...               ...       ...        ...       ...        ...       ...
# 2022-04-19  35.209999  5.940000  35.209999  5.940000  36.680000  6.020000
# 2022-04-20  35.160000  5.610000  35.160000  5.610000  35.270000  6.040000
# 2022-04-22  34.430000  5.550000  34.430000  5.550000  34.770000  5.590000
# 2022-04-25  34.700001  5.440000  34.700001  5.440000  34.950001  5.570000
# 2022-04-26  33.919998  5.180000  33.919998  5.180000  34.560001  5.470000
#
#                   Low                 Open              Volume
#              BBAS3.SA  MGLU3.SA   BBAS3.SA  MGLU3.SA  BBAS3.SA   MGLU3.SA
# Date
# 2018-01-02  32.090000  2.450312  32.090000  2.528125   9178100   59427200
# 2018-01-03  32.820000  2.422500  33.099998  2.468750   8180700   41385600
# 2018-01-04  33.450001  2.478125  33.520000  2.500000   9625200   47936000
# 2018-01-05  33.290001  2.448437  33.700001  2.514062   5267800   30684800
# 2018-01-08  33.340000  2.448437  33.639999  2.453125   5130600   28796800
# ...               ...       ...        ...       ...       ...        ...
# 2022-04-19  35.049999  5.760000  36.380001  5.850000  17886500   85633600
# 2022-04-20  34.810001  5.580000  35.240002  5.940000  11296200  114800300
# 2022-04-22  34.150002  5.420000  34.730000  5.480000  10923400   81060300
# 2022-04-25  33.970001  5.370000  34.250000  5.440000  11322400  111425500
# 2022-04-26  33.500000  5.180000  34.400002  5.400000  13915900   83066900
#
# [1067 rows x 12 columns]

# %%
meu_nome = "Carlos"
esposa = "Fernanda"
filho = "Theo"
filha = "Raquel"

# %%
lista_de_nomes = [meu_nome, esposa, filho, filha]

# %%
lista_de_nomes
# Out:
# ['Carlos', 'Fernanda', 'Theo', 'Raquel']

# %%
qs.extend_pandas()

# %%
bbas3 = qs.utils.download_returns("bbas3.sa")

# %%
bbas3.monthly_returns()
# Out:
#            JAN       FEB       MAR       APR       MAY       JUN       JUL  \
# 2000 -0.036586 -0.056963 -0.155705 -0.046104 -0.066668  0.151787 -0.031007
# 2001  0.326633 -0.087122  0.005533  0.189821 -0.092486  0.222930 -0.080208
# 2002 -0.150142  0.193334  0.080074  0.162931 -0.028910 -0.313741 -0.041157
# 2003 -0.018367 -0.002079  0.096876  0.206077  0.204725 -0.144445  0.084799
# 2004 -0.150000  0.061274  0.075289 -0.179553  0.089005  0.081731  0.022223
# 2005 -0.049230  0.003236 -0.045162 -0.011824  0.049572  0.030945 -0.011059
# 2006  0.268958  0.018861  0.017228  0.092793 -0.073372 -0.110677 -0.001600
# 2007  0.085937 -0.012949 -0.027843  0.043635  0.137930  0.056440  0.061312
# 2008 -0.037829 -0.033505 -0.182525  0.250540  0.125952 -0.196374 -0.040153
# 2009 -0.032697 -0.024648  0.218050  0.094250  0.146263  0.009857  0.116147
# 2010 -0.029361  0.076227  0.009591  0.004690 -0.120863 -0.051193  0.238946
# 2011 -0.052833  0.010414  0.000699 -0.018951 -0.026820  0.007997 -0.060715
# 2012  0.147258  0.022652 -0.051268 -0.091329 -0.149412 -0.009076  0.116231
# 2013 -0.046875  0.079509  0.041671 -0.061338  0.009718 -0.120879  0.027651
# 2014 -0.143852 -0.002722  0.118921  0.025877 -0.018026  0.099137  0.115493
# 2015 -0.130837  0.152429 -0.018708  0.161938 -0.129816  0.081309 -0.091845
# 2016 -0.060380 -0.022382  0.475473  0.118361 -0.249184  0.051790  0.225262
# 2017  0.107512  0.063967  0.023196 -0.027243 -0.131334 -0.051599  0.070896
# 2018  0.247015  0.053428 -0.010801 -0.105532 -0.166894 -0.053832  0.134380
# 2019  0.115509 -0.013319 -0.023116  0.019704  0.052549  0.043683 -0.087505
# 2020 -0.081030 -0.025925 -0.401824  0.021872  0.082105  0.042477  0.044479
# 2021 -0.127320 -0.158872  0.090851 -0.026601  0.144228 -0.036020 -0.015562
# 2022  0.132062  0.078077  0.015513 -0.022478  0.000000  0.000000  0.000000
#
#            AUG       SEP       OCT       NOV       DEC       EOY
# 2000 -0.014400  0.014611 -0.065601 -0.025685  0.049209 -0.245323
# 2001  0.014721 -0.176339  0.043360  0.183117  0.162459  0.709603
# 2002  0.263342 -0.264462  0.217228  0.038974 -0.032577  0.068982
# 2003  0.084506  0.038961  0.175000  0.303192 -0.020408  0.966361
# 2004  0.054347  0.039175  0.123413  0.125044  0.020408  0.374055
# 2005  0.114696  0.243909 -0.046083 -0.053140  0.076531  0.329061
# 2006 -0.038076 -0.010417  0.093473  0.138814  0.081995  0.525272
# 2007 -0.047297  0.095389  0.013273  0.015974 -0.044025  0.422637
# 2008 -0.052191 -0.043716 -0.350769 -0.031822  0.026574 -0.486263
# 2009  0.114968  0.201358 -0.096702  0.099706 -0.057002  0.792912
# 2010 -0.061157  0.135680  0.030190 -0.002162 -0.038646  0.180935
# 2011  0.024593 -0.059941  0.042673 -0.060868 -0.008792 -0.166052
# 2012  0.068994  0.082138 -0.126210  0.016272  0.183578  0.199847
# 2013  0.054268  0.136213  0.150870 -0.133198 -0.038901  0.089316
# 2014  0.273205 -0.273628  0.096048  0.073485 -0.188608  0.161280
# 2015 -0.185191 -0.133445  0.050658  0.029507 -0.080856 -0.264814
# 2016  0.109574 -0.012213  0.284649 -0.023183 -0.011433  0.848767
# 2017  0.076825  0.139377 -0.013181 -0.125061  0.066015  0.228861
# 2018 -0.065219 -0.018557  0.451613  0.053963  0.044730  0.504696
# 2019 -0.051608 -0.011421  0.058474  0.000816  0.108872  0.236681
# 2020 -0.014475 -0.089877  0.006077  0.142808  0.149388 -0.079108
# 2021 -0.026631 -0.044321 -0.013841  0.132542 -0.088961 -0.171214
# 2022  0.000000  0.000000  0.000000  0.000000  0.000000  0.202979

# %%
bbas3.plot_monthly_heatmap()

# %%
dir(qs.stats)

# %%
bbas3.volatility()
# Out:
# 0.4368010675091397

# %%
qs.reports.basic(bbas3, benchmark="^BVSP")
# Out:
# [Performance Metrics]
#
#                     Strategy    Benchmark
# ------------------  ----------  -----------
# Start Period        2000-01-03  2000-01-03
# End Period          2022-04-26  2022-04-26
# Risk-Free Rate      0.0%        0.0%
# Time in Market      98.0%       100.0%
#
# Cumulative Return   2,736.64%   539.18%
# CAGR﹪              16.16%      8.66%
#
# Sharpe              0.57        0.44
# Sortino             0.85        0.63
# Sortino/√2          0.6         0.44
# Omega               1.1         1.1
#
# Max Drawdown        -64.94%     -59.96%
# Longest DD Days     1077        3400
#
# Gain/Pain Ratio     0.1         0.08
# Gain/Pain (1M)      0.59        0.45
#
# Payoff Ratio        1.06        0.99
# Profit Factor       1.1         1.08
# Common Sense Ratio  1.24        1.05
# CPC Index           0.59        0.55
# Tail Ratio          1.12        0.97
# Outlier Win Ratio   3.04        4.73
# Outlier Loss Ratio  2.83        4.3
#
# MTD                 -2.25%      -9.82%
# 3M                  12.03%      -0.67%
# 6M                  23.23%      1.8%
# YTD                 21.15%      3.23%
# 1Y                  22.74%      -10.22%
# 3Y (ann.)           -6.25%      3.99%
# 5Y (ann.)           6.88%       10.78%
# 10Y (ann.)          10.64%      5.78%
# All-time (ann.)     16.16%      8.66%
#
# Avg. Drawdown       -9.41%      -4.67%
# Avg. Drawdown Days  68          64
# Recovery Factor     42.14       8.99
# Ulcer Index         0.25        0.22
# Serenity Index      6.77        1.11
#
#
#
# [Strategy Visualization]
# via Matplotlib

# %%
qs.reports.full(bbas3, benchmark="^BVSP")
# Out:
# [Performance Metrics]
#
#                            Strategy    Benchmark
# -------------------------  ----------  -----------
# Start Period               2000-01-03  2000-01-03
# End Period                 2022-04-26  2022-04-26
# Risk-Free Rate             0.0%        0.0%
# Time in Market             98.0%       100.0%
#
# Cumulative Return          2,736.64%   539.18%
# CAGR﹪                     16.16%      8.66%
#
# Sharpe                     0.57        0.44
# Smart Sharpe               0.56        0.44
# Sortino                    0.85        0.63
# Smart Sortino              0.84        0.62
# Sortino/√2                 0.6         0.44
# Smart Sortino/√2           0.6         0.44
# Omega                      1.1         1.1
#
# Max Drawdown               -64.94%     -59.96%
# Longest DD Days            1077        3400
# Volatility (ann.)          43.68%      28.32%
# R^2                        0.5         0.5
# Calmar                     0.25        0.14
# Skew                       0.22        -0.13
# Kurtosis                   4.89        6.25
#
# Expected Daily %           0.06%       0.03%
# Expected Monthly %         1.26%       0.69%
# Expected Yearly %          15.66%      8.4%
# Kelly Criterion            4.29%       3.29%
# Risk of Ruin               0.0%        0.0%
# Daily Value-at-Risk        -4.43%      -2.88%
# Expected Shortfall (cVaR)  -4.43%      -2.88%
#
# Gain/Pain Ratio            0.1         0.08
# Gain/Pain (1M)             0.59        0.45
#
# Payoff Ratio               1.06        0.99
# Profit Factor              1.1         1.08
# Common Sense Ratio         1.24        1.05
# CPC Index                  0.59        0.55
# Tail Ratio                 1.12        0.97
# Outlier Win Ratio          3.04        4.73
# Outlier Loss Ratio         2.83        4.3
#
# MTD                        -2.25%      -9.82%
# 3M                         12.03%      -0.67%
# 6M                         23.23%      1.8%
# YTD                        21.15%      3.23%
# 1Y                         22.74%      -10.22%
# 3Y (ann.)                  -6.25%      3.99%
# 5Y (ann.)                  6.88%       10.78%
# 10Y (ann.)                 10.64%      5.78%
# All-time (ann.)            16.16%      8.66%
#
# Best Day                   20.71%      14.66%
# Worst Day                  -21.17%     -14.78%
# Best Month                 47.55%      17.92%
# Worst Month                -40.18%     -29.9%
# Best Year                  144.9%      97.34%
# Worst Year                 -51.71%     -41.22%
#
# Avg. Drawdown              -9.41%      -4.67%
# Avg. Drawdown Days         68          64
# Recovery Factor            42.14       8.99
# Ulcer Index                0.25        0.22
# Serenity Index             6.77        1.11
#
# Avg. Up Month              11.28%      6.74%
# Avg. Down Month            -8.45%      -5.83%
# Win Days %                 50.82%      51.93%
# Win Month %                53.36%      55.22%
# Win Quarter %              54.44%      58.89%
# Win Year %                 69.57%      60.87%
# Beta                       1.09        -
# Alpha                      0.11        -
#
#
#
# [5 Worst Drawdowns]
#
#     Start       Valley      End           Days    Max Drawdown    99% Max Drawdown
# --  ----------  ----------  ----------  ------  --------------  ------------------
#  1  2008-06-02  2008-11-21  2009-10-14     499          -64.94              -60.42
#  2  2014-09-03  2016-01-27  2017-01-26     876          -61.54              -60.96
#  3  2020-01-03  2020-03-23  2022-04-26     844          -58.29              -51.58
#  4  2002-04-15  2002-09-30  2003-05-30     410          -47.30              -44.67
#  5  2018-03-12  2018-06-18  2018-10-30     232          -43.25              -41.44
#
#
#
# [Strategy Visualization]
# via Matplotlib

# %%
lista_ativos = ["BBAS3.SA", "MGLU3.SA"]
dados_ativos = yf.download(lista_ativos, start='2018-01-01', period='1D')["High"]

# %%
dados_ativos

# %%
# URL BASE
DATA_PATH = "http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/ITR/DADOS/"
DATA_2021_PATH = "http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/ITR/DADOS/itr_cia_aberta_2021.zip"

# %%
wget.download(DATA_2021_PATH)
ZipFile("itr_cia_aberta_2021.zip", 'r').extractall('CVM_2021')

# %%
dre = pd.read_csv(f'/content/CVM/itr_cia_aberta_DRE_ind_2021.csv', encoding="iso8859-1")
